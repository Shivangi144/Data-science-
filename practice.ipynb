# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivangi144/Data-science-/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  dic={"class":[10,11,12],"student":["ram","siya","rima"]}
  c=10
  s="riya"
  if c in dic["class"]:
    print("class is present")
  else:
    print("class not present")
  if s in dic["student"]:
    print("siya is present")
  else:
    print("siya is not present")
#
# Out:
# class is present
# siya is not present

# %%
L=["Shivangi",30,90,"False"]
i=0
for i<len[L]:
print(L[i])
i+=1
print(i,L)
# Out:
#   File "/tmp/ipykernel_1000/3260042849.py", line 3
#     for i<len[L]:
#          ^
# SyntaxError: invalid syntax

# %%
a=30
b=80
print(a,b)
print(id(a),id(b))
#
a=40
b=45
a=b
print(a,b)
print(id(a),id(b))
#arithmetic operators
a=80
b=40
print(a+b)
print(a*b)
print(a/b)
print(a//b)
print(a-b)
print(a%b)

#relational operator
c=50
d=86
print(c<=d)
print(c>=d)
print(c==d)
print(c != d)

num1=80
num2=70
print(num1>=num2)
print(num1 != num2)

#assignment operator
b=60
b +=30
print(b)

c=50
c -=45
print(c)
#logical operator
a=26
b=56
print(a and b)
print(a or b)
#
name1="hello"
name2=""
print(name1 and name2)
print(name1 or name2)

a=34
b=100
print(a>50 and b<90)
print(a<60 or b>80)

num1=95
print(not(num1  <82))
print(not(num1 < 120))

a=[]
b=45
print(a and b)

c=["Shivangi","20"]
d={}
print(c or d)
print(c and d)
# Out:
# 30 80
# 11646280 11647880
# 45 45
# 11646760 11646760
# 120
# 3200
# 2.0
# 2
# 40
# 0
# True
# False
# False
# True
# True
# True
# 90
# 5
# 56
# 26
#
# hello
# False
# True
# True
# False
# []
# ['Shivangi', '20']
# {}
