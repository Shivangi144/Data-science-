# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivangi144/Data-science-/blob/main/ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {'Name':['Shivangi','Siya','Sachi'],
'Age':[20,None,25],
'Salary':[80000,60000,None]}
df = pd.DataFrame(data)
print("original Dataframe")
print(df)
#
df.isnull()

#fill
df['Age'] ==df['Age'].fillna(24)
df.fillna({'Age': 24, 'Salary': 50000})

# drop n
df.dropna()
# Out:
# original Dataframe
#        Name   Age   Salary
# 0  Shivangi  20.0  80000.0
# 1      Siya   NaN  60000.0
# 2     Sachi  25.0      NaN
#        Name   Age   Salary
# 0  Shivangi  20.0  80000.0

# %% [markdown]
# Label Encoding

# %%
#  label encoding
from sklearn.preprocessing import LabelEncoder
import pandas as pd
data = {'Name':['Shivangi','Siya','Sachi','Priya','Yash'],
'Age':[20,17,None,19,27],
'Salary':[85000,70000,65000,None,95000],
'Gender':['female','female','female','female',None]}

df = pd.DataFrame(data)
print("Original Dataframe")
print(df)

# label encoder
le = LabelEncoder()
df_label = df.copy()
df_label['Gender'] = df['Gender'].fillna('male')
df_label['Gender_encoder']= le.fit_transform(df_label['Gender'])
print('After label encoding')
print(df_label)

# %%
# one hot encoding
import pandas as pd
data = {'Colors':['red','black','blue','maroon','green','blue']}
df = pd.DataFrame(data)
print("original data")
print(df)
# one hot encoding
encoded_df = pd.get_dummies(df,columns = ['Colors'])
print("after one hot encoding")
print(encoded_df)
# Out:
# original data
#    Colors
# 0     red
# 1   black
# 2    blue
# 3  maroon
# 4   green
# 5    blue
# after one hot encoding
#    Colors_black  Colors_blue  Colors_green  Colors_maroon  Colors_red
# 0         False        False         False          False        True
# 1          True        False         False          False       False
# 2         False         True         False          False       False
# 3         False        False         False           True       False
# 4         False        False          True          False       False
# 5         False         True         False          False       False

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
data = {
    "Age":[20,24,np.nan,26,28],
    "Gender":['female','female','female',np.nan,'female'],
    "Name":['Shivangi','Addie','Siya','Raj','Sachi']
}
df = pd.DataFrame(data)
#
df['Age'] = df['Age'].fillna(df['Age'].mean())
df.dropna(subset=['Gender'],inplace = True)
print(df)

#label encoding
le = LabelEncoder()
df['Gender']= le.fit_transform(df['Gender'])
print(df)

# one hot encoding
oe = OneHotEncoder()
oe_e = oe.fit_transform(df[['Gender']]).toarray()
print(oe_e)
# Out:
#     Age  Gender      Name
# 0  20.0  female  Shivangi
# 1  24.0  female     Addie
# 2  24.5  female      Siya
# 4  28.0  female     Sachi
#     Age  Gender      Name
# 0  20.0       0  Shivangi
# 1  24.0       0     Addie
# 2  24.5       0      Siya
# 4  28.0       0     Sachi
# [[1.]
#  [1.]
#  [1.]
#  [1.]]

# %%
#feature scaling
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
data = {
    "Experience": [3,5,10,4],
    "Salary":[90000,70000,92000,80000],
}
df = pd.DataFrame(data)
print(df)

#std scaler
scaler = StandardScaler()
df["Experience"] = scaler.fit_transform(df[["Experience"]])
print(df)

# split data
X = df["Experience"]
y = df["Salary"]
print(X)
print(y)
plt.plot(df['Experience'],df['Salary'],color = 'green',marker = 'o')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.title('Experience vs Salary')
plt.show()
# Out:
#    Experience  Salary
# 0           3   90000
# 1           5   70000
# 2          10   92000
# 3           4   80000
#    Experience  Salary
# 0   -0.928477   90000
# 1   -0.185695   70000
# 2    1.671258   92000
# 3   -0.557086   80000
# 0   -0.928477
# 1   -0.185695
# 2    1.671258
# 3   -0.557086
# Name: Experience, dtype: float64
# 0    90000
# 1    70000
# 2    92000
# 3    80000
# Name: Salary, dtype: int64

# %%
# data split
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
url = "https://raw.githubusercontent.com/rajendra0968jangid/Ds-Arya/main/extended_salary_data.csv"
df = pd.read_csv(url)
print(df)
# split data
X = df['experience']
y = df['salary']

# train test split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state=2)
print("x train:"),x_train
print("x test: ",x_test)
print("y train: ", y_train)
print("y test: ", y_test)
# Out:
#      experience  salary
# 0           300    1000
# 1           600    1500
# 2           900    2000
# 3          1500    3000
# 4          1800    3500
# ..          ...     ...
# 99        30300   51000
# 100       30600   51500
# 101       30900   52000
# 102       31200   52500
# 103       31500   53000
#
# [104 rows x 2 columns]
# x train:
# x test:  81    24900
# 30     9600
# 60    18600
# 24     7800
# 16     5400
# 23     7500
# 2       900
# 27     8700
# 28     9000
# 13     4500
# 83    25500
# 96    29400
# 80    24600
# 14     4800
# 0       300
# 21     6900
# 3      1500
# 29     9300
# 98    30000
# 44    13800
# 35    11100
# Name: experience, dtype: int64
# y train:  11     7000
# 88    45500
# 61    32000
# 73    38000
# 5      4000
#       ...
# 43    23000
# 22    12500
# 72    37500
# 15     9000
# 40    21500
# Name: salary, Length: 83, dtype: int64
# y test:  81    42000
# 30    16500
# 60    31500
# 24    13500
# 16     9500
# 23    13000
# 2      2000
# ...

# %%
# simple linear reg | prediction
from sklearn.linear_model import LinearRegression

# model fit
model = LinearRegression()
model.fit(x_train,y_train) # 2d

# input from user
user = int(input("Enter your Experience: "))
# model prediction

new_data = {
    "experience":[user]
}

df1 = pd.DataFrame(new_data)
print(df1)
pred_data = model.predict(df1)
print(pred_data[0])
